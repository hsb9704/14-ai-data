# %%
# Do not reinvert the wheel  (바퀴를 다시 만들지마라)

# %%
from faker import Faker


fake = Faker()
fake.name()
# Out:
# 'Vicki Taylor'

# %%
fake.address()
# Out:
# '6732 Odonnell Divide\nNicholastown, NC 47521'

# %%
test_data = [(fake.name() , fake.address()) for _ in range(30)]
print(test_data)
# Out:
# [('Jordan Vargas', '960 Lloyd Mills\nLynchtown, UT 02286'), ('Travis Townsend', '5288 Julie Ville Apt. 303\nJeromeshire, MH 48114'), ('Shane Willis', '967 Fisher Mount\nEast Ian, TN 60847'), ('Michael Rivas', '837 Steven Plains\nBarbaratown, RI 49454'), ('Eileen Anderson', '001 Payne Trail\nWest Triciatown, MP 73843'), ('Melissa Wheeler', '241 Miller Lakes\nAngelaville, AR 32710'), ('Robert Estrada', '548 Vasquez Bridge\nPort Sherylhaven, WY 80580'), ('Kyle Williams', '20287 King Island\nEast Kevin, CT 16018'), ('Casey Flores', '939 Patricia Locks\nLindseyburgh, GU 69884'), ('Michael Duncan', '60565 Elizabeth Estates Suite 194\nRobertfort, AZ 79024'), ('Madeline Lee', '9676 James Brooks\nPaulhaven, MS 72924'), ('Shaun Cruz', '93171 Karen Rue Suite 949\nDonnaton, DC 92278'), ('James Johnson', '6310 Kim Flat\nEast Edwardmouth, VT 53861'), ('Andrea Webb', '8613 Odonnell Lake Suite 179\nPamelaland, CT 36077'), ('Tom Lyons', '46295 Robert Ferry Suite 632\nSouth Angelabury, MA 59317'), ('J
# ...
