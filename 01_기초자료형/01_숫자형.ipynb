# %%
# 정수형
a = 123
b = -170
c = 0

type(a)
# Out:
# int

# %%
# 실수형
a = 1.2E10
b = 4.3E-10
c = 3.14

type(c)
a #print(a)
type(a)
# Out:
# float

# %%
# 8진수와 16진수
a = 0o177
a
# Out:
# 127

# %%
8 ** 2 + 8 * 7 +7
# Out:
# 127

# %%
a = 0x8ff
a
# Out:
# 2303

# %%
(16 ** 2 * 8) + (16 * 16) + 15
# Out:
# 2319

# %%
# 사칙연산
a = 3
b = 4

print(a + b)
print(a - b)
print(a*b)
print(a/b)
# Out:
# 7
# -1
# 12
# 0.75

# %%
a
# Out:
# 3

# %%
a = 3
b = 4
a ** b
# Out:
# 81

# %%
16 ** 1/2
# Out:
# 8.0

# %%
# 나눗셈 후 나머지를 반환하는 % 연산자
7 % 3
# Out:
# 1

# %%
7/3
# Out:
# 2.3333333333333335

# %%
# 나눗셈 후 몫을 반환하는 // 연산자
7 // 3
# Out:
# 2

# %%
# 복합 연산자
a = 1
a = a + 1

print(a)
# Out:
# 2

# %%
a = 1
a += 1 # a = a + 2
print(a)
# Out:
# 2

# %%
print(a)


a -= 1 # a = a - 1
a += 1 # a = a * 1
a
