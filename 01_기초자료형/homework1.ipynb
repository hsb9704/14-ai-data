# %%
a = "hello world"

print(a[6]+a[0])
# Out:
# wh

# %%
a = ["Hi"]
print(a * 3)
# Out:
# ['Hi', 'Hi', 'Hi']

# %%
a =[]
a.append(10)
a.append(20)
a.extend(30)
a.extend([40, 50])
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 4
#       2 a.append(10)
#       3 a.append(20)
# ----> 4 a.extend(30)
#       5 a.extend([40, 50])
#       6 print(a)
#
# TypeError: 'int' object is not iterable
