# %%
# 변수는 어떻게 만들까
# 변수이름 = 변수에 저장할 값

# 변수명 규칙
# 1. 영문자 , 숫자, 언더스코어(..) 만 사용할 수 있다.
# 2. 숫자로는 시작할 수 없음.
# 3. 예약어(명령어)는 변수로 사용할 수 없다.(ex: print, del 등등) --이후에 기능이 사라짐
# 4. 대소문자 구분을 한다.



name = "홍길동"
# 1name = "유재석"   안됨
name2= "강호동"

# user-name ="홍길동"  안됨
user_namer ="홍길동"
print(user_namer)

#컨벤션 
# user_namer(0)  스네이크스타일 --- 권장
#userName(0) 낙타스타일
#UserName(0) 파스칼
# Out:
# 홍길동

# %%
a = [1,2,3]
print(id(a))
b = [1,2,3]
print(id(b))
a.append(4)
print(a)
print(id(a))      #a 의 주소가 바뀌지않았다. 메모리에 재선언한것
b= a
print(id(b))      #b 의 주소가 a와 같아졌다.
# Out:
# 2319179513408
# 2319179513600
# [1, 2, 3, 4]
# 2319179513408
# 2319179513408

# %%
a =[1,2,3]
b =a[:]         #복사의 개념
print(id(a))
print(id(b))    #복사하여 새롭게 생성된 개념
# Out:
# 2319179216896
# 2319179530176

# %%
# 변수를 만드는 여러가지 방법

a ,b = ["pyton","like"]     #구조분해 양쪽 요소의 갯수가 같아야함.
print(a)
print(b)

print(type(a))
print(type(b))
# Out:
# pyton
# 2
# <class 'str'>
# <class 'int'>

# %%
(a ,b) = "pyton","like"     
print(a)
print(b)

print(type(a))
print(type(b))
# Out:
# pyton
# like
# <class 'str'>
# <class 'str'>

# %%
a = b = "python"

print(a)
print(b)
print(type(a))
# Out:
# python
# python
# <class 'str'>

# %%
a = 3
b= 5
a,b = b ,a   #언팩
print(a)
print(b)
# Out:
# 5
# 3
