# %%
# 리스트는 어떻게 만들까? (대괄호는 리스트형)
# 형식

# a = 0, 1 
a = []
b = [1, 2, 3]
c = ["Life", "is", "too", "short"]
d = [1, 2, "Life", "is"]
e = [1, 2, ["life", "is"]]

print(type(a))
print(len(a))
print(len(b))
print(len(c))
print(len(d))
print(len(e))
# Out:
# <class 'list'>
# 0
# 3
# 4
# 4
# 3

# %%
# 리스트의 인덱싱
a = ["Life", "is", "too", "short"] 
print(a[2])
print(a[-1])
print(a[0][3])
# Out:
# too
# short
# e

# %%
a = [1, 2, 3]
a[0] + a[2]
# Out:
# 4

# %%
a = [1, 2, 3,["a", "b", "c"]]
print(a[-1])
print(a[-1][1])
# Out:
# ['a', 'b', 'c']
# b

# %%
# 리스트의 슬라이싱
a = [1, 2, 3, 4, 5]
a[0:2]
# Out:
# [1, 2]

# %%
a[-2:]
# Out:
# [4, 5]

# %%
# 리스트 연산하기
# 1. 리스트 더하기

a = [1, 2, 3]
b = [4 ,5 ,6]
print(a + b)

# 2. 리스트 곱하기
a = [1, 2, 3]
print(a * 3)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# 리스트의 수정과 삭제
# 1. 리스트의 값 수정하기

a = [1, 2, 3]
a[2] = 4
print(a)

# 2. 리스트의 요소 삭제하기
a = [1, 2, 3]
del a[1]
print(a)

a = [1, 2, 3, 4, 5]
del a[2:]
print(a)
# Out:
# [1, 2, 4]
# [1, 3]
# [1, 2]

# %%
# 리스트 관련 함수 (*중요)
# 1. 리스트에 요소 추가하기 - append

a = [1, 2, 3]
a.append(4)
print(a)
a.append([5, 6])
print(a)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4, [5, 6]]

# %%
# 2. 리스트 정렬 - sort
a = [1, 4, 3, 2]
# 오름차순
a.sort()
print(a)

# 내림차순
a.sort(reverse=True)
print(a)
# Out:
# [1, 2, 3, 4]
# [4, 3, 2, 1]

# %%
# 3. 리스트 뒤집기 - reverse
a = ["a", "c", "b"]
# a.sort()
# print(a)
a.reverse()
print(a)
# Out:
# ['b', 'c', 'a']

# %%
# 4. 인덱스 번호 - index

a = [5, 4, 3, 2, 1]
print(a.index(3))
print(a.index(2))
# Out:
# 2
# 3

# %%
# 5. 리스트에 요소 삽입 - insert

a = [1, 2, 3]

a.insert(0, 4)
print(a)
# Out:
# [4, 1, 2, 3]

# %%
# 6. 리스트에 요소 제거 - remove

a = [1, 2, 3, 1, 2, 3]
a.remove(3)
print(a)
# Out:
# [1, 2, 1, 2, 3]

# %%
# 7. 리스트 요소 꺼내기 - pop
a = [1, 2, 3]
result1 = a.pop()
print(a)
print(result1)
# Out:
# [1, 2]
# 3

# %%
# 8. 요소의 개수 세기 - count
a = [1, 2, 3, 1]
a.count(1)
# Out:
# 2

# %%
# 9. 리스트 확장 - extend
a = [1, 2, 3]
a.extend([4, 5])
print(a)
# Out:
# [1, 2, 3, 4, 5]
