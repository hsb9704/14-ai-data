# %%
# 튜플은 어떻게 만들까?

a= ()
b= (1,) #하나의 요소가 있는 튜플을 만들때 뒤에 콤마를 적어줘야함 인수와 구분하기 위해
c =(1 ,2, 3)
d= 1, 2, 3  #괄호 생략가능
e = ("a","b", "ab", "cd")
f = 1,
g= 1
print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
print(type(f))
print(type(g))
# Out:
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'int'>

# %%
# 튜플 요소값을 삭제하려고할때 --안됨
a = (1 ,2 ,"a", "b")
del a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # 튜플 요소값을 삭제하려고할때
#       2 a = (1 ,2 ,"a", "b")
# ----> 3 del a[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
# 튜플 요소값을 변경하려 할때    --안됨           삭제와 재할당은 안되지만 변경은 가능
a = (1 ,2 ,"a", "b")
a[0] ="c"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # 튜플 요소값을 변경하려 할때
#       2 a = (1 ,2 ,"a", "b")
# ----> 3 a[0] ="c"
#
# TypeError: 'tuple' object does not support item assignment

# %%
a= (1,2)    #메모리위에 객체를 가르킨다
a = a*2
print(a)
# Out:
# (1, 2, 1, 2)

# %%
a =10
print(id(a))
a= 20
print(id(a))
# Out:
# 140726528988568
# 140726528988888

# %%
a =[1,2,3]
print(id(a))

a.append(4)
print(a)
print(id(a))
# Out:
# 2163904305856
# [1, 2, 3, 4]
# 2163904305856

# %%
# 튜플 인덱싱하기
a = (1,2,3,4)
print(a[0])
# Out:
# 1

# %%
#튜플 슬라이싱하기
a = (1,2,3,4)
print(a[:2])
# Out:
# (1, 2)

# %%
# 튜플 더하기
a = (1,2)
b = (3,4)
c = a+ b
print(c)
# Out:
# (1, 2, 3, 4)

# %%
#  튜플 곱하기
a =(3 ,4)
b= a*3
print(b)
# Out:
# (3, 4, 3, 4, 3, 4)

# %%
#  튜플 길이구하기
a = (1,2,3,4)
len(a)
# Out:
# 4
